# %% [markdown]
# # Movie Analysis & Extraction

# %% [markdown]
# ### Import Dependencies

# %%
#Data Cleaning
import pandas as pd
import numpy as np
from scipy.stats import linregress

#Data Visualization
import matplotlib.pyplot as plt
import seaborn as sn

# Data Extraction
import requests
import json
import time
from sqlalchemy import create_engine

# %% [markdown]
# ## Import CSV file

# %%
#csv --> df of four sources

metacritic_df = pd.read_csv('./Resources/metacritic_movies.csv')
mojo_budget_df = pd.read_csv('./Resources/Mojo_budget_data.csv')

# %%
metacritic_df
# Out:
#               movie_title release_date                         genre  \
# 0     Anatomy of a Murder     1-Jul-59  Drama,Mystery,Thriller,Crime
# 1        Bringing Up Baby    18-Feb-38         Comedy,Romance,Family
# 2              After Life    12-May-99                 Drama,Fantasy
# 3                 Gavagai     3-Aug-18                         Drama
# 4             The Hustler    25-Sep-61                   Drama,Sport
# ...                   ...          ...                           ...
# 9116           Wild Reeds    10-May-95                         Drama
# 9117        No Home Movie     1-Apr-16                   Documentary
# 9118                Solas     8-Sep-00                         Drama
# 9119           J.T. Leroy    26-Apr-19               Biography,Drama
# 9120           Donnybrook    15-Feb-19                         Drama
#
#       meta_mixed  meta_negative  meta_positive  metascore user_mixed  \
# 0              0              0             15         95          0
# 1              0              1             16         91          1
# 2              0              0             19         91          0
# 3              1              0              6         91          0
# 4              1              0             17         90          0
# ...          ...            ...            ...        ...        ...
# 9116           2              0             11         80          1
# 9117           3              0              7         78          1
# 9118           2              0             14         75          1
# 9119          13              0             10         55          2
# 9120           3              4              8         53          1
#
#      user_negative user_positive userscore
# 0                0             3       tbd
# 1                0             2       tbd
# 2                2             1       tbd
# 3                1             2       tbd
# 4                0             3       tbd
# ...            ...           ...       ...
# 9116             0             3         8
# 9117             0             3       7.8
# 9118             0             3       7.5
# 9119             1             1       5.5
# 9120             1             2       5.3
#
# [9121 rows x 11 columns]

# %%
mojo_budget_df
# Out:
#        movie_id         movie_title  movie_year            director  \
# 0     tt0118589             Glitter        2001  Vondie Curtis-Hall
# 1     tt0120630         Chicken Run        2000          Peter Lord
# 2     tt0120667      Fantastic Four        2005           Tim Story
# 3     tt0120679               Frida        2002        Julie Taymor
# 4     tt0120681           From Hell        2001       Albert Hughes
# ...         ...                 ...         ...                 ...
# 2471  tt8688634          21 Bridges        2019          Brian Kirk
# 2472  tt8946378          Knives Out        2019        Rian Johnson
# 2473  tt9024106           Unplanned        2019     Chuck Konzelman
# 2474  tt9134216   Playing with Fire        2019        Andy Fickman
# 2475  tt9173418  Brahms: The Boy II        2020  William Brent Bell
#
#               writer            producer                composer  \
# 0     Cheryl L. West       Laurence Mark       Terence Blanchard
# 1         Peter Lord          Peter Lord  Harry Gregson-Williams
# 2         Mark Frost            Avi Arad             John Ottman
# 3     Hayden Herrera  Lindsay Flickinger       Elliot Goldenthal
# 4         Alan Moore        Jane Hamsher            Trevor Jones
# ...              ...                 ...                     ...
# 2471     Adam Mervis    Chadwick Boseman            Alex Belcher
# 2472    Rian Johnson         Ram Bergman          Nathan Johnson
# 2473    Abby Johnson         Chris Jones   Stephen Blake Kanicka
# 2474        Dan Ewen         Todd Garner             Nathan Wang
# 2475   Stacey Menear       Matt Berenson             Brett Detar
#
#              cinematographer      main_actor_1        main_actor_2  ...  \
# 0           Geoffrey Simpson      Mariah Carey          Eric Benét  ...
# 1               Simon Jacobs        Mel Gibson       Julia Sawalha  ...
# 2                Oliver Wood     Ioan Gruffudd     Michael Chiklis  ...
# 3             Rodrigo Prieto       Salma Hayek       Alfred Molina  ...
# 4               Peter Deming       Johnny Depp      Heather Graham  ...
# ...                      ...               ...                 ...  ...
# 2471            Paul Cameron  Chadwick Boseman       Sienna Miller  ...
# 2472            Steve Yedlin      Daniel Craig         Chris Evans  ...
# 2473                Drew Maw   Ashley Bratcher         Brooks Ryan  ...
# 2474             Dean Semler         John Cena  Keegan-Michael Key  ...
# 2475  Karl Walter Lindenlaub      Katie Holmes        Owain Yeoman  ...
#
#        domestic international  worldwide   mpaa     run_time    genre_1  \
# 0       4274407        997259    5271666  PG-13  1 hr 44 min      Drama
# 1     106834564     118000000  224834564    NaN  1 hr 24 min  Adventure
# 2     154696080     178839854  333535934  PG-13  1 hr 46 min     Action
# 3      25885000      30413474   56298474      R   2 hr 3 min  Biography
# 4      31602566      42955549   74558115      R   2 hr 2 min     Horror
# ...         ...           ...        ...    ...          ...        ...
# 2471   28539757      21400000   49939757      R  1 hr 39 min     Action
# 2472  165363234     146189956  311553190  PG-13  2 hr 11 min     Comedy
# 2473   19005109       2046806   21051915      R  1 hr 49 min  Biography
# 2474   44451847      24179822   68631669     PG  1 hr 36 min     Comedy
# 2475   12611536       7700000   20311536  PG-13  1 hr 26 min      Drama
#
#         genre_2   genre_3   genre_4  \
# 0         Music   Romance       NaN
# 1     Animation    Comedy     Drama
# 2     Adventure    Family   Fantasy
# 3         Drama   Romance       NaN
# 4       Mystery  Thriller       NaN
# ...         ...       ...       ...
# 2471      Crime     Drama  Thriller
# 2472      Crime     Drama   Mystery
# 2473      Drama       NaN       NaN
# 2474     Family       NaN       NaN
# 2475     Horror   Mystery  Thriller
#
#                                                    link
# 0     https://www.boxofficemojo.com/title/tt0118589/...
# 1     https://www.boxofficemojo.com/title/tt0120630/...
# 2     https://www.boxofficemojo.com/title/tt0120667/...
# 3     https://www.boxofficemojo.com/title/tt0120679/...
# 4     https://www.boxofficemojo.com/title/tt0120681/...
# ...                                                 ...
# 2471  https://www.boxofficemojo.com/title/tt8688634/...
# 2472  https://www.boxofficemojo.com/title/tt8946378/...
# 2473  https://www.boxofficemojo.com/title/tt9024106/...
# 2474  https://www.boxofficemojo.com/title/tt9134216/...
# 2475  https://www.boxofficemojo.com/title/tt9173418/...
#
# [2476 rows x 23 columns]

# %% [markdown]
# ### CSV Data Cleaning

# %%
#dropping columns with irrelevant data

cleaned_mojo_df= mojo_budget_df.drop(columns= ['movie_id','director', 'writer', 'producer', 'composer', 'cinematographer', 'main_actor_1', 'main_actor_2', 'main_actor_3', 'main_actor_4', 'genre_2', 'genre_3', 'genre_4', 'link' ])

cleaned_mojo_df
# Out:
#              movie_title  movie_year     budget   domestic  international  \
# 0                Glitter        2001   22000000    4274407         997259
# 1            Chicken Run        2000   45000000  106834564      118000000
# 2         Fantastic Four        2005  100000000  154696080      178839854
# 3                  Frida        2002   12000000   25885000       30413474
# 4              From Hell        2001   35000000   31602566       42955549
# ...                  ...         ...        ...        ...            ...
# 2471          21 Bridges        2019   33000000   28539757       21400000
# 2472          Knives Out        2019   40000000  165363234      146189956
# 2473           Unplanned        2019    6000000   19005109        2046806
# 2474   Playing with Fire        2019   29900000   44451847       24179822
# 2475  Brahms: The Boy II        2020   10000000   12611536        7700000
#
#       worldwide   mpaa     run_time    genre_1
# 0       5271666  PG-13  1 hr 44 min      Drama
# 1     224834564    NaN  1 hr 24 min  Adventure
# 2     333535934  PG-13  1 hr 46 min     Action
# 3      56298474      R   2 hr 3 min  Biography
# 4      74558115      R   2 hr 2 min     Horror
# ...         ...    ...          ...        ...
# 2471   49939757      R  1 hr 39 min     Action
# 2472  311553190  PG-13  2 hr 11 min     Comedy
# 2473   21051915      R  1 hr 49 min  Biography
# 2474   68631669     PG  1 hr 36 min     Comedy
# 2475   20311536  PG-13  1 hr 26 min      Drama
#
# [2476 rows x 9 columns]

# %%
metacritic_df
# Out:
#               movie_title release_date                         genre  \
# 0     Anatomy of a Murder     1-Jul-59  Drama,Mystery,Thriller,Crime
# 1        Bringing Up Baby    18-Feb-38         Comedy,Romance,Family
# 2              After Life    12-May-99                 Drama,Fantasy
# 3                 Gavagai     3-Aug-18                         Drama
# 4             The Hustler    25-Sep-61                   Drama,Sport
# ...                   ...          ...                           ...
# 9116           Wild Reeds    10-May-95                         Drama
# 9117        No Home Movie     1-Apr-16                   Documentary
# 9118                Solas     8-Sep-00                         Drama
# 9119           J.T. Leroy    26-Apr-19               Biography,Drama
# 9120           Donnybrook    15-Feb-19                         Drama
#
#       meta_mixed  meta_negative  meta_positive  metascore user_mixed  \
# 0              0              0             15         95          0
# 1              0              1             16         91          1
# 2              0              0             19         91          0
# 3              1              0              6         91          0
# 4              1              0             17         90          0
# ...          ...            ...            ...        ...        ...
# 9116           2              0             11         80          1
# 9117           3              0              7         78          1
# 9118           2              0             14         75          1
# 9119          13              0             10         55          2
# 9120           3              4              8         53          1
#
#      user_negative user_positive userscore
# 0                0             3       tbd
# 1                0             2       tbd
# 2                2             1       tbd
# 3                1             2       tbd
# 4                0             3       tbd
# ...            ...           ...       ...
# 9116             0             3         8
# 9117             0             3       7.8
# 9118             0             3       7.5
# 9119             1             1       5.5
# 9120             1             2       5.3
#
# [9121 rows x 11 columns]

# %%
cleaned_metacritic_df= metacritic_df.drop(columns= ['release_date', 'genre'])
cleaned_metacritic_df
# Out:
#               movie_title  meta_mixed  meta_negative  meta_positive  \
# 0     Anatomy of a Murder           0              0             15
# 1        Bringing Up Baby           0              1             16
# 2              After Life           0              0             19
# 3                 Gavagai           1              0              6
# 4             The Hustler           1              0             17
# ...                   ...         ...            ...            ...
# 9116           Wild Reeds           2              0             11
# 9117        No Home Movie           3              0              7
# 9118                Solas           2              0             14
# 9119           J.T. Leroy          13              0             10
# 9120           Donnybrook           3              4              8
#
#       metascore user_mixed user_negative user_positive userscore
# 0            95          0             0             3       tbd
# 1            91          1             0             2       tbd
# 2            91          0             2             1       tbd
# 3            91          0             1             2       tbd
# 4            90          0             0             3       tbd
# ...         ...        ...           ...           ...       ...
# 9116         80          1             0             3         8
# 9117         78          1             0             3       7.8
# 9118         75          1             0             3       7.5
# 9119         55          2             1             1       5.5
# 9120         53          1             1             2       5.3
#
# [9121 rows x 9 columns]

# %%
# Merge dfs on movie_title
movie_db_df = pd.merge(cleaned_mojo_df, cleaned_metacritic_df, how="left", on="movie_title")
movie_db_df
# Out:
#              movie_title  movie_year     budget   domestic  international  \
# 0                Glitter        2001   22000000    4274407         997259
# 1            Chicken Run        2000   45000000  106834564      118000000
# 2         Fantastic Four        2005  100000000  154696080      178839854
# 3         Fantastic Four        2005  100000000  154696080      178839854
# 4                  Frida        2002   12000000   25885000       30413474
# ...                  ...         ...        ...        ...            ...
# 2580          21 Bridges        2019   33000000   28539757       21400000
# 2581          Knives Out        2019   40000000  165363234      146189956
# 2582           Unplanned        2019    6000000   19005109        2046806
# 2583   Playing with Fire        2019   29900000   44451847       24179822
# 2584  Brahms: The Boy II        2020   10000000   12611536        7700000
#
#       worldwide   mpaa     run_time    genre_1  meta_mixed  meta_negative  \
# 0       5271666  PG-13  1 hr 44 min      Drama         3.0           20.0
# 1     224834564    NaN  1 hr 24 min  Adventure         1.0            0.0
# 2     333535934  PG-13  1 hr 46 min     Action        18.0           11.0
# 3     333535934  PG-13  1 hr 46 min     Action        18.0           21.0
# 4      56298474      R   2 hr 3 min  Biography        17.0            1.0
# ...         ...    ...          ...        ...         ...            ...
# 2580   49939757      R  1 hr 39 min     Action         NaN            NaN
# 2581  311553190  PG-13  2 hr 11 min     Comedy         NaN            NaN
# 2582   21051915      R  1 hr 49 min  Biography         1.0            6.0
# 2583   68631669     PG  1 hr 36 min     Comedy         NaN            NaN
# 2584   20311536  PG-13  1 hr 26 min      Drama         NaN            NaN
#
#       meta_positive  metascore user_mixed user_negative user_positive  \
# 0               0.0       14.0          9            59            31
# 1              33.0       88.0         36             9           258
# 2               6.0       40.0        161           177           305
# 3               1.0       27.0        176           627           109
# 4              20.0       61.0          4             2            34
# ...             ...        ...        ...           ...           ...
# 2580            NaN        NaN        NaN           NaN           NaN
# 2581            NaN        NaN        NaN           NaN           NaN
# 2582            0.0       10.0          1            51           687
# 2583            NaN        NaN        NaN           NaN           NaN
# 2584            NaN        NaN        NaN           NaN           NaN
#
#      userscore
# 0          3.6
# 1          8.2
# 2          5.7
# 3          2.6
# 4          7.4
# ...        ...
# 2580       NaN
# 2581       NaN
# 2582       9.3
# 2583       NaN
# 2584       NaN
#
# [2585 rows x 17 columns]

# %%
final_movie_db_df=movie_db_df.drop_duplicates(subset=["movie_title", "movie_year"])
final_movie_db_df
# Out:
#              movie_title  movie_year     budget   domestic  international  \
# 0                Glitter        2001   22000000    4274407         997259
# 1            Chicken Run        2000   45000000  106834564      118000000
# 2         Fantastic Four        2005  100000000  154696080      178839854
# 4                  Frida        2002   12000000   25885000       30413474
# 5              From Hell        2001   35000000   31602566       42955549
# ...                  ...         ...        ...        ...            ...
# 2580          21 Bridges        2019   33000000   28539757       21400000
# 2581          Knives Out        2019   40000000  165363234      146189956
# 2582           Unplanned        2019    6000000   19005109        2046806
# 2583   Playing with Fire        2019   29900000   44451847       24179822
# 2584  Brahms: The Boy II        2020   10000000   12611536        7700000
#
#       worldwide   mpaa     run_time    genre_1  meta_mixed  meta_negative  \
# 0       5271666  PG-13  1 hr 44 min      Drama         3.0           20.0
# 1     224834564    NaN  1 hr 24 min  Adventure         1.0            0.0
# 2     333535934  PG-13  1 hr 46 min     Action        18.0           11.0
# 4      56298474      R   2 hr 3 min  Biography        17.0            1.0
# 5      74558115      R   2 hr 2 min     Horror        10.0            7.0
# ...         ...    ...          ...        ...         ...            ...
# 2580   49939757      R  1 hr 39 min     Action         NaN            NaN
# 2581  311553190  PG-13  2 hr 11 min     Comedy         NaN            NaN
# 2582   21051915      R  1 hr 49 min  Biography         1.0            6.0
# 2583   68631669     PG  1 hr 36 min     Comedy         NaN            NaN
# 2584   20311536  PG-13  1 hr 26 min      Drama         NaN            NaN
#
#       meta_positive  metascore user_mixed user_negative user_positive  \
# 0               0.0       14.0          9            59            31
# 1              33.0       88.0         36             9           258
# 2               6.0       40.0        161           177           305
# 4              20.0       61.0          4             2            34
# 5              15.0       54.0         23            37            54
# ...             ...        ...        ...           ...           ...
# 2580            NaN        NaN        NaN           NaN           NaN
# 2581            NaN        NaN        NaN           NaN           NaN
# 2582            0.0       10.0          1            51           687
# 2583            NaN        NaN        NaN           NaN           NaN
# 2584            NaN        NaN        NaN           NaN           NaN
#
#      userscore
# 0          3.6
# 1          8.2
# 2          5.7
# 4          7.4
# 5          5.2
# ...        ...
# 2580       NaN
# 2581       NaN
# 2582       9.3
# 2583       NaN
# 2584       NaN
#
# [2475 rows x 17 columns]

# %%
final_movie_db_df=final_movie_db_df.rename(columns= {"movie_title":"Title", "movie_year":"Year", "budget":"Budget", "domestic":"Domestic Revenue", "international":"International Revenue", "worldwide":"Worldwide Revenue", "mpaa":"MPAA Rating", "run_time":"Run Time", "genre_1":"Genre", "meta_mixed":"Metacritic Mixed Reviews", "meta_negative":"Metacritic Negative Reviews", "meta_positive":"Metacritic Positive Reviews", "metascore":"Metascore", "user_mixed":"Users Mixed Reviews", "user_negative":"Users Negative Reviews", "user_positive":"Users Positive Reviews", "userscore": "Userscore"})
final_movie_db_df
# Out:
#                    Title  Year     Budget  Domestic Revenue  \
# 0                Glitter  2001   22000000           4274407
# 1            Chicken Run  2000   45000000         106834564
# 2         Fantastic Four  2005  100000000         154696080
# 4                  Frida  2002   12000000          25885000
# 5              From Hell  2001   35000000          31602566
# ...                  ...   ...        ...               ...
# 2580          21 Bridges  2019   33000000          28539757
# 2581          Knives Out  2019   40000000         165363234
# 2582           Unplanned  2019    6000000          19005109
# 2583   Playing with Fire  2019   29900000          44451847
# 2584  Brahms: The Boy II  2020   10000000          12611536
#
#       International Revenue  Worldwide Revenue MPAA Rating     Run Time  \
# 0                    997259            5271666       PG-13  1 hr 44 min
# 1                 118000000          224834564         NaN  1 hr 24 min
# 2                 178839854          333535934       PG-13  1 hr 46 min
# 4                  30413474           56298474           R   2 hr 3 min
# 5                  42955549           74558115           R   2 hr 2 min
# ...                     ...                ...         ...          ...
# 2580               21400000           49939757           R  1 hr 39 min
# 2581              146189956          311553190       PG-13  2 hr 11 min
# 2582                2046806           21051915           R  1 hr 49 min
# 2583               24179822           68631669          PG  1 hr 36 min
# 2584                7700000           20311536       PG-13  1 hr 26 min
#
#           Genre  Metacritic Mixed Reviews  Metacritic Negative Reviews  \
# 0         Drama                       3.0                         20.0
# 1     Adventure                       1.0                          0.0
# 2        Action                      18.0                         11.0
# 4     Biography                      17.0                          1.0
# 5        Horror                      10.0                          7.0
# ...         ...                       ...                          ...
# 2580     Action                       NaN                          NaN
# 2581     Comedy                       NaN                          NaN
# 2582  Biography                       1.0                          6.0
# 2583     Comedy                       NaN                          NaN
# 2584      Drama                       NaN                          NaN
#
#       Metacritic Positive Reviews  Metascore Users Mixed Reviews  \
# 0                             0.0       14.0                   9
# 1                            33.0       88.0                  36
# 2                             6.0       40.0                 161
# 4                            20.0       61.0                   4
# 5                            15.0       54.0                  23
# ...                           ...        ...                 ...
# 2580                          NaN        NaN                 NaN
# 2581                          NaN        NaN                 NaN
# 2582                          0.0       10.0                   1
# 2583                          NaN        NaN                 NaN
# 2584                          NaN        NaN                 NaN
#
#      Users Negative Reviews Users Positive Reviews Userscore
# 0                        59                     31       3.6
# 1                         9                    258       8.2
# 2                       177                    305       5.7
# 4                         2                     34       7.4
# 5                        37                     54       5.2
# ...                     ...                    ...       ...
# 2580                    NaN                    NaN       NaN
# 2581                    NaN                    NaN       NaN
# 2582                     51                    687       9.3
# 2583                    NaN                    NaN       NaN
# 2584                    NaN                    NaN       NaN
#
# [2475 rows x 17 columns]

# %%
final_movie_db_df = final_movie_db_df.replace('tbd', np.nan)
final_movie_db_df
# Out:
#                    Title  Year     Budget  Domestic Revenue  \
# 0                Glitter  2001   22000000           4274407
# 1            Chicken Run  2000   45000000         106834564
# 2         Fantastic Four  2005  100000000         154696080
# 4                  Frida  2002   12000000          25885000
# 5              From Hell  2001   35000000          31602566
# ...                  ...   ...        ...               ...
# 2580          21 Bridges  2019   33000000          28539757
# 2581          Knives Out  2019   40000000         165363234
# 2582           Unplanned  2019    6000000          19005109
# 2583   Playing with Fire  2019   29900000          44451847
# 2584  Brahms: The Boy II  2020   10000000          12611536
#
#       International Revenue  Worldwide Revenue MPAA Rating     Run Time  \
# 0                    997259            5271666       PG-13  1 hr 44 min
# 1                 118000000          224834564         NaN  1 hr 24 min
# 2                 178839854          333535934       PG-13  1 hr 46 min
# 4                  30413474           56298474           R   2 hr 3 min
# 5                  42955549           74558115           R   2 hr 2 min
# ...                     ...                ...         ...          ...
# 2580               21400000           49939757           R  1 hr 39 min
# 2581              146189956          311553190       PG-13  2 hr 11 min
# 2582                2046806           21051915           R  1 hr 49 min
# 2583               24179822           68631669          PG  1 hr 36 min
# 2584                7700000           20311536       PG-13  1 hr 26 min
#
#           Genre  Metacritic Mixed Reviews  Metacritic Negative Reviews  \
# 0         Drama                       3.0                         20.0
# 1     Adventure                       1.0                          0.0
# 2        Action                      18.0                         11.0
# 4     Biography                      17.0                          1.0
# 5        Horror                      10.0                          7.0
# ...         ...                       ...                          ...
# 2580     Action                       NaN                          NaN
# 2581     Comedy                       NaN                          NaN
# 2582  Biography                       1.0                          6.0
# 2583     Comedy                       NaN                          NaN
# 2584      Drama                       NaN                          NaN
#
#       Metacritic Positive Reviews  Metascore Users Mixed Reviews  \
# 0                             0.0       14.0                   9
# 1                            33.0       88.0                  36
# 2                             6.0       40.0                 161
# 4                            20.0       61.0                   4
# 5                            15.0       54.0                  23
# ...                           ...        ...                 ...
# 2580                          NaN        NaN                 NaN
# 2581                          NaN        NaN                 NaN
# 2582                          0.0       10.0                   1
# 2583                          NaN        NaN                 NaN
# 2584                          NaN        NaN                 NaN
#
#      Users Negative Reviews Users Positive Reviews Userscore
# 0                        59                     31       3.6
# 1                         9                    258       8.2
# 2                       177                    305       5.7
# 4                         2                     34       7.4
# 5                        37                     54       5.2
# ...                     ...                    ...       ...
# 2580                    NaN                    NaN       NaN
# 2581                    NaN                    NaN       NaN
# 2582                     51                    687       9.3
# 2583                    NaN                    NaN       NaN
# 2584                    NaN                    NaN       NaN
#
# [2475 rows x 17 columns]

# %%
final_movie_db_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2475 entries, 0 to 2584
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        2475 non-null   object
#  1   Year                         2475 non-null   int64
#  2   Budget                       2475 non-null   int64
#  3   Domestic Revenue             2475 non-null   int64
#  4   International Revenue        2475 non-null   int64
#  5   Worldwide Revenue            2475 non-null   int64
#  6   MPAA Rating                  2413 non-null   object
#  7   Run Time                     2475 non-null   object
#  8   Genre                        2475 non-null   object
#  9   Metacritic Mixed Reviews     2283 non-null   float64
#  10  Metacritic Negative Reviews  2283 non-null   float64
#  11  Metacritic Positive Reviews  2283 non-null   float64
#  12  Metascore                    2283 non-null   float64
#  13  Users Mixed Reviews          2283 non-null   object
#  14  Users Negative Reviews       2283 non-null   object
#  15  Users Positive Reviews       2283 non-null   object
#  16  Userscore                    2278 non-null   object
# dtypes: float64(4), int64(5), object(8)
# memory usage: 348.0+ KB

# %%
print(final_movie_db_df.isnull().sum())
# Out:
# Title                            0
# Year                             0
# Budget                           0
# Domestic Revenue                 0
# International Revenue            0
# Worldwide Revenue                0
# MPAA Rating                     62
# Run Time                         0
# Genre                            0
# Metacritic Mixed Reviews       192
# Metacritic Negative Reviews    192
# Metacritic Positive Reviews    192
# Metascore                      192
# Users Mixed Reviews            192
# Users Negative Reviews         192
# Users Positive Reviews         192
# Userscore                      197
# dtype: int64

# %%
final_movie_db_df["Userscore"] = final_movie_db_df.Userscore.astype(float)

# %%
final_movie_db_df.fillna(final_movie_db_df.mean())
# Out:
#                    Title  Year     Budget  Domestic Revenue  \
# 0                Glitter  2001   22000000           4274407
# 1            Chicken Run  2000   45000000         106834564
# 2         Fantastic Four  2005  100000000         154696080
# 4                  Frida  2002   12000000          25885000
# 5              From Hell  2001   35000000          31602566
# ...                  ...   ...        ...               ...
# 2580          21 Bridges  2019   33000000          28539757
# 2581          Knives Out  2019   40000000         165363234
# 2582           Unplanned  2019    6000000          19005109
# 2583   Playing with Fire  2019   29900000          44451847
# 2584  Brahms: The Boy II  2020   10000000          12611536
#
#       International Revenue  Worldwide Revenue MPAA Rating     Run Time  \
# 0                    997259            5271666       PG-13  1 hr 44 min
# 1                 118000000          224834564         NaN  1 hr 24 min
# 2                 178839854          333535934       PG-13  1 hr 46 min
# 4                  30413474           56298474           R   2 hr 3 min
# 5                  42955549           74558115           R   2 hr 2 min
# ...                     ...                ...         ...          ...
# 2580               21400000           49939757           R  1 hr 39 min
# 2581              146189956          311553190       PG-13  2 hr 11 min
# 2582                2046806           21051915           R  1 hr 49 min
# 2583               24179822           68631669          PG  1 hr 36 min
# 2584                7700000           20311536       PG-13  1 hr 26 min
#
#           Genre  Metacritic Mixed Reviews  Metacritic Negative Reviews  \
# 0         Drama                  3.000000                    20.000000
# 1     Adventure                  1.000000                     0.000000
# 2        Action                 18.000000                    11.000000
# 4     Biography                 17.000000                     1.000000
# 5        Horror                 10.000000                     7.000000
# ...         ...                       ...                          ...
# 2580     Action                 11.341656                     5.542269
# 2581     Comedy                 11.341656                     5.542269
# 2582  Biography                  1.000000                     6.000000
# 2583     Comedy                 11.341656                     5.542269
# 2584      Drama                 11.341656                     5.542269
#
#       Metacritic Positive Reviews  Metascore Users Mixed Reviews  \
# 0                         0.00000  14.000000                   9
# 1                        33.00000  88.000000                  36
# 2                         6.00000  40.000000                 161
# 4                        20.00000  61.000000                   4
# 5                        15.00000  54.000000                  23
# ...                           ...        ...                 ...
# 2580                     15.08629  52.588261                 NaN
# 2581                     15.08629  52.588261                 NaN
# 2582                      0.00000  10.000000                   1
# 2583                     15.08629  52.588261                 NaN
# 2584                     15.08629  52.588261                 NaN
#
#      Users Negative Reviews Users Positive Reviews  Userscore
# 0                        59                     31   3.600000
# 1                         9                    258   8.200000
# 2                       177                    305   5.700000
# 4                         2                     34   7.400000
# 5                        37                     54   5.200000
# ...                     ...                    ...        ...
# 2580                    NaN                    NaN   6.543854
# 2581                    NaN                    NaN   6.543854
# 2582                     51                    687   9.300000
# 2583                    NaN                    NaN   6.543854
# 2584                    NaN                    NaN   6.543854
#
# [2475 rows x 17 columns]

# %% [markdown]
# ### Save to CSV for future use

# %%
#Save df to csv

#random_name_csv.to_csv('./Resources/Random_name2.csv',index=False)

final_movie_db_df.to_csv('./Resources/movie_db.csv', index=False, header=True)

# %%
final_movie_db_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2475 entries, 0 to 2584
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Title                        2475 non-null   object
#  1   Year                         2475 non-null   int64
#  2   Budget                       2475 non-null   int64
#  3   Domestic Revenue             2475 non-null   int64
#  4   International Revenue        2475 non-null   int64
#  5   Worldwide Revenue            2475 non-null   int64
#  6   MPAA Rating                  2413 non-null   object
#  7   Run Time                     2475 non-null   object
#  8   Genre                        2475 non-null   object
#  9   Metacritic Mixed Reviews     2283 non-null   float64
#  10  Metacritic Negative Reviews  2283 non-null   float64
#  11  Metacritic Positive Reviews  2283 non-null   float64
#  12  Metascore                    2283 non-null   float64
#  13  Users Mixed Reviews          2283 non-null   object
#  14  Users Negative Reviews       2283 non-null   object
#  15  Users Positive Reviews       2283 non-null   object
#  16  Userscore                    2278 non-null   float64
# dtypes: float64(5), int64(5), object(7)
# memory usage: 348.0+ KB

# %%
final_movie_db_df.describe()
# Out:
#               Year        Budget  Domestic Revenue  International Revenue  \
# count  2475.000000  2.475000e+03      2.475000e+03           2.475000e+03
# mean   2008.868283  5.055986e+07      6.680369e+07           8.810686e+07
# std       5.631900  4.956858e+07      8.275647e+07           1.509255e+08
# min    2000.000000  2.200000e+02      8.000000e+03           9.990000e+02
# 25%    2004.000000  1.600000e+07      1.695038e+07           7.737332e+06
# 50%    2009.000000  3.500000e+07      3.978503e+07           3.384364e+07
# 75%    2014.000000  6.900000e+07      8.306080e+07           9.788564e+07
# max    2020.000000  3.560000e+08      9.366622e+08           2.029931e+09
#
#        Worldwide Revenue  Metacritic Mixed Reviews  \
# count       2.475000e+03               2283.000000
# mean        1.549105e+08                 11.341656
# std         2.256294e+08                  6.112211
# min         7.962400e+04                  0.000000
# 25%         2.967042e+07                  7.000000
# 50%         7.602513e+07                 11.000000
# 75%         1.805854e+08                 16.000000
# max         2.797801e+09                 36.000000
#
#        Metacritic Negative Reviews  Metacritic Positive Reviews    Metascore  \
# count                  2283.000000                  2283.000000  2283.000000
# mean                      5.542269                    15.086290    52.588261
# std                       5.721045                    12.097254    17.387562
# min                       0.000000                     0.000000     9.000000
# 25%                       1.000000                     5.000000    40.000000
# 50%                       4.000000                    12.000000    52.000000
# 75%                       9.000000                    24.000000    65.000000
# max                      30.000000                    56.000000   100.000000
#
#          Userscore
# count  2278.000000
# mean      6.543854
# std       1.537691
# min       1.000000
# 25%       5.600000
# 50%       6.700000
# 75%       7.700000
# max       9.400000

# %%
engine=create_engine("sqlite:///final_movie_db.sqlite", echo=True)
sqlite_connection=engine.connect()
# Out:
# 2021-06-15 21:00:17,934 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2021-06-15 21:00:17,935 INFO sqlalchemy.engine.base.Engine ()
# 2021-06-15 21:00:17,936 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2021-06-15 21:00:17,936 INFO sqlalchemy.engine.base.Engine ()

# %%
sqlite_table="final_movie"
final_movie_db_df.to_sql(sqlite_table, sqlite_connection, if_exists="fail")
# Out:
# 2021-06-15 21:00:17,957 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("final_movie")
# 2021-06-15 21:00:17,958 INFO sqlalchemy.engine.base.Engine ()
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-f4a2eb7a1740> in <module>
#       1 sqlite_table="final_movie"
# ----> 2 final_movie_db_df.to_sql(sqlite_table, sqlite_connection, if_exists="fail")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1391             dtype=dtype,
#    1392         )
# -> 1393         table.create()
#    1394
#    1395         from sqlalchemy import exc
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     721         if self.exists():
#     722             if self.if_exists == "fail":
# --> 723                 raise ValueError(f"Table '{self.name}' already exists.")
#     724             elif self.if_exists == "replace":
#     725                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'final_movie' already exists.

# %%
sqlite_connection.close()
